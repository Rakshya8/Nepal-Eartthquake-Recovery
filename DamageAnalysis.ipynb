# %%
# import pandas as pd
# import pyreadstat

# # Load the .sav file
# df, meta = pyreadstat.read_sav("D:/AIT/SET_RA/Nepal-Eartthquake-Recovery/Data_damage/EQ_Micro/data/Building.sav")

# # Save to .csv
# df.to_csv("D:/AIT/SET_RA/Nepal-Eartthquake-Recovery/Data_damage/EQ_Micro/data/csv/Building.csv", index=False)

# print("Conversion complete: your_file.csv")
# Out:
# Conversion complete: your_file.csv

# %%
import pandas as pd
df = pd.read_csv("D:/AIT/SET_RA/Nepal-Eartthquake-Recovery/Data_damage/EQ_Micro/data/csv/Building.csv")
df.head(5)
# Out:
#    dist  vcode  vdcmun  ward   EA  howner_sn  house_sn  legl_own  house_cd  \
# 0   7.0   71.0     1.0   2.0  0.0        1.0       1.0       1.0       7.0
# 1   7.0   71.0     1.0   2.0  0.0        2.0       1.0       1.0       7.0
# 2   7.0   71.0     1.0   2.0  0.0        3.0       1.0       1.0       7.0
# 3   7.0   71.0     1.0   3.0  0.0        1.0       1.0       1.0       7.0
# 4   7.0   71.0     1.0   3.0  0.0        2.0       1.0       1.0       2.0
#
#    floor_pre  ...  secuse_ls2  secuse_ls3  secuse_ls4  secuse_ls5  secuse_ls6  \
# 0        1.0  ...         NaN         NaN         NaN         NaN         NaN
# 1        1.0  ...         NaN         NaN         NaN         NaN         NaN
# 2        2.0  ...         NaN         NaN         NaN         NaN         NaN
# 3        2.0  ...         NaN         NaN         NaN         NaN         NaN
# 4        1.0  ...         NaN         NaN         NaN         NaN         NaN
#
# ...
